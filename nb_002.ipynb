# %%
# !pip install geocoder
import pandas as pd
import geocoder

# %%
df = pd.read_csv('fixed.csv')
df.head()
# Out:
#   Postcode           Borough                    Neighbourhood
# 0      M3A        North York                        Parkwoods
# 1      M4A        North York                 Victoria Village
# 2      M5A  Downtown Toronto         Harbourfront;Regent Park
# 3      M6A        North York  Lawrence Heights;Lawrence Manor
# 4      M7A      Queen's Park                     Queen's Park

# %%
'''
latlist = []
longlist =[]

def getlatlong(postalcode):
    latlong = None
    while latlong == None:
        g = geocoder.google(postalcode)
        latlong = g.latlng
    return latlong
j = 0
for i in df['Postcode']:
    result = getlatlong(i)
    latlist.append(result[0])
    longlist.append(result[1])
    if j%10 ==0:
        print("working")
    j+=1
'''    
extender = pd.read_csv("Geospatial_Coordinates.csv")
extender.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
latlist = []
longlist = []
for i in df['Postcode']:
    k = 0
    for j in extender['Postal Code']:
        if i == j:
            latlist.append(extender['Latitude'][k])
            longlist.append(extender['Longitude'][k])
            
            break
        k+=1
nextender = pd.DataFrame({'Latitude':latlist, 'Longitude':longlist})
df['Latitude'] = nextender['Latitude']
df['Longitude'] = nextender['Longitude']

# %%
df.head(10)
# Out:
#   Postcode           Borough                    Neighbourhood   Latitude  \
# 0      M3A        North York                        Parkwoods  43.753259
# 1      M4A        North York                 Victoria Village  43.725882
# 2      M5A  Downtown Toronto         Harbourfront;Regent Park  43.654260
# 3      M6A        North York  Lawrence Heights;Lawrence Manor  43.718518
# 4      M7A      Queen's Park                     Queen's Park  43.662301
# 5      M9A         Etobicoke                 Islington Avenue  43.667856
# 6      M1B       Scarborough                    Rouge;Malvern  43.806686
# 7      M3B        North York                  Don Mills North  43.745906
# 8      M4B         East York   Woodbine Gardens;Parkview Hill  43.706397
# 9      M5B  Downtown Toronto          Ryerson;Garden District  43.657162
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494
# 5 -79.532242
# 6 -79.194353
# 7 -79.352188
# 8 -79.309937
# 9 -79.378937

# %%
df.to_csv("fixedwithll.csv", index = False)# for further use if needed
